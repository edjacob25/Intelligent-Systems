# %%
from aima.agents import Environment, Thing, Agent
from collections import namedtuple


Position = namedtuple("Position", "x y")


class AlphaEnvironment(Environment):
    
    def __init__(self, map_items, height=6, width=6):
        super().__init__()
        self.width = width
        self.height = height
        self.matrix = [[None for _ in range(height)] for _ in range(width)]
        for thing in map_items:
            self.matrix[thing["x"]][thing["y"]] = thing["item"] 
        self.print_board()
          
    def percept(self, agent):
        pass

    def execute_action(self, agent, action):
        pass
    
    def print_board(self):
        for row in self.matrix:
            print("-" * (len(row) * 2 - 1))
            for item in row:
                if isinstance(item, ArrowTrap):
                    label = "T"
                elif isinstance(item, Idol):
                    label = "I"
                else:
                    label = "-"
                
                print("|{}".format(label), end="")
            print("|")
        print("-" * (len(self.matrix[0]) * 2 - 1))


class ArrowTrap(Thing):
    pass


class Idol(Thing):
    pass


class Explorer(Agent):
    def __init__(self, position=None, program=None):
        super().__init__(program)
        if position is None:
            self.x = 0
            self.y = 0
        else:
            self.x = position.x
            self.y = position.y
            
        self.performance = 0
    
    def percept(self, percept):
        pass
    
    def move(self, direction):
        if direction == "Up":
            self.y -= 1
        if direction == "Down":
            self.y += 1
        if direction == "Right":
            self.x += 1
        if direction == "Left":
            self.x -= 1
    
    def take(self):
        self.performance += 10


def program():
    pass


items = [{"x": 1, "y": 1, "item": Idol()}, 
         {"x": 4, "y": 5, "item": ArrowTrap()}]
a = AlphaEnvironment(items)
a.execute_action("", "")
exp = Explorer()
print("Pos: {},{}".format(exp.x, exp.y))
exp.move("Down")
print("Pos: {},{}".format(exp.x, exp.y))
# Out:
# -----------
# |-|-|-|-|-|-|
# -----------
# |-|I|-|-|-|-|
# -----------
# |-|-|-|-|-|-|
# -----------
# |-|-|-|-|-|-|
# -----------
# |-|-|-|-|-|T|
# -----------
# |-|-|-|-|-|-|
# -----------
# Pos: 0,0
# Pos: 0,1
